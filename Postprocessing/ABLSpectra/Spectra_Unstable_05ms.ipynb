# %%
# %%capture

# Change some display properties
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
import matplotlib.pyplot as plt
import numpy as np
import windspectra
import os.path
from matplotlib.lines import Line2D
# %matplotlib inline

# %%
# Average the spectra over multiple locations
# given by locations in planefilelist
def avgSpectraPlanefiles(planefilelist, verbose=True):
    # set initial values
    iplane = 0
    all_ulongavgs = []
    lent = 0
    # Loop through and get spectra
    for planefile in planefilelist:
        if not os.path.isfile(datadir+'/'+planefile): continue
        dat       = np.loadtxt(datadir+'/'+planefile)
        t   = dat[:,0]
        z   = dat[:,6]
        u   = dat[:,7]
        v   = dat[:,8]
        w   = dat[:,9]
        if ((iplane != 0) and (lent != len(t))): continue
        if verbose: print("Loaded plane "+planefile)
        ulong, ulat = windspectra.convertUxytoLongLat(u,v)
        all_ulongavgs.append(np.mean(ulong))
        f, Suu      = windspectra.avgWindSpectra(t, ulong, avgbins)
        f, Svv      = windspectra.avgWindSpectra(t, ulat,  avgbins)
        f, Sww      = windspectra.avgWindSpectra(t, w,     avgbins)
        if iplane == 0:
            lent    = len(t)
            favg    = f
            Suu_avg = Suu
            Svv_avg = Svv
            Sww_avg = Sww
        else:
            Suu_avg = Suu_avg + Suu
            Svv_avg = Svv_avg + Svv
            Sww_avg = Sww_avg + Sww
        iplane = iplane+1
        zavg   = np.mean(z)
    # Average the spectra
    Suu_avg = Suu_avg/iplane
    Svv_avg = Svv_avg/iplane
    Sww_avg = Sww_avg/iplane
    if verbose: print("Averaged over %i planes"%iplane)
    return favg, Suu_avg, Svv_avg, Sww_avg, np.mean(all_ulongavgs), zavg

# %%
# Define some dicts to save stuff
Suu_avg={}
Svv_avg={}
Sww_avg={}
avgUlong={}
zavg={}
favg={}
Su_Kai={}
Sv_Kai={}
Sw_Kai={}

# %%
# Define data locations and variables
#datadir  = '/ascldap/users/lcheung/nscratch/Torque2020/Runs/unstable/05ms/mini05_iter13/statsData/extractpoints/HHplane_plane0'
datadir = '/ascldap/users/lcheung/nscratch/Torque2020/Runs/unstable/05ms/05ms_iter01/statsData/extractpoints/HHplane_plane0'
planeprefix = 'HHplane_'
planenum = 0
#jvector  = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54] 
#ivector  = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54] 
jvector  = range(0,221,20) # [0, 40, 80, 120, 160, 200] 
ivector  = range(0,221,20) # [0, 40, 80, 120, 160, 200] 

# Averaging bins
#avgbins  = [[15500,  16800], [16150, 17450]] 
#avgbins  = [[15500.5,  17500], [16500, 18500]] 
#avgbins  = [[15500.5,  18100], [16800.5, 19400]] 
#avgbins = []
#avgbins = [[14500.5, 16100.5],[15300.5,16900.5]]
#avgbins = [[14500.5, 17100.5],[15800.5,18400.5]]
#avgbins = [[14500.5, 17700.5], [16100.5,19300.5]]
avgbins = [[14500.5, 18160.5], [16330.5,19990.5]]
#avgbins = [[25000.5, 26300], [25650.5, 26950]]

# Friction velocity.  Eventually this should be pulled from the ABL stats file
utau     = 0.1635

# %%
# Construct the list of planefiles and average
s='20'
planefiles=[]
for j in jvector:
    for i in ivector:
        planefiles.append(planeprefix+'%i_%i_%i.dat'%(planenum, j,i))
favg[s], Suu_avg[s], Svv_avg[s], Sww_avg[s], avgUlong[s], zavg[s] = avgSpectraPlanefiles(planefiles, verbose=True)
# Out:
# Loaded plane HHplane_0_0_0.dat
# Loaded plane HHplane_0_0_20.dat
# Loaded plane HHplane_0_0_40.dat
# Loaded plane HHplane_0_0_60.dat
# Loaded plane HHplane_0_0_80.dat
# Loaded plane HHplane_0_0_100.dat
# Loaded plane HHplane_0_0_120.dat
# Loaded plane HHplane_0_0_140.dat
# Loaded plane HHplane_0_0_160.dat
# Loaded plane HHplane_0_0_180.dat
# Loaded plane HHplane_0_0_200.dat
# Loaded plane HHplane_0_0_220.dat
# Loaded plane HHplane_0_20_0.dat
# Loaded plane HHplane_0_20_20.dat
# Loaded plane HHplane_0_20_40.dat
# Loaded plane HHplane_0_20_60.dat
# Loaded plane HHplane_0_20_80.dat
# Loaded plane HHplane_0_20_100.dat
# Loaded plane HHplane_0_20_120.dat
# Loaded plane HHplane_0_20_140.dat
# Loaded plane HHplane_0_20_160.dat
# Loaded plane HHplane_0_20_180.dat
# Loaded plane HHplane_0_20_200.dat
# Loaded plane HHplane_0_20_220.dat
# Loaded plane HHplane_0_40_0.dat
# Loaded plane HHplane_0_40_20.dat
# Loaded plane HHplane_0_40_40.dat
# Loaded plane HHplane_0_40_60.dat
# Loaded plane HHplane_0_40_80.dat
# Loaded plane HHplane_0_40_100.dat
# Loaded plane HHplane_0_40_120.dat
# Loaded plane HHplane_0_40_140.dat
# Loaded plane HHplane_0_40_160.dat
# Loaded plane HHplane_0_40_180.dat
# Loaded plane HHplane_0_40_200.dat
# Loaded plane HHplane_0_40_220.dat
# Loaded plane HHplane_0_60_0.dat
# Loaded plane HHplane_0_60_20.dat
# Loaded plane HHplane_0_60_40.dat
# Loaded plane HHplane_0_60_60.dat
# Loaded plane HHplane_0_60_80.dat
# Loaded plane HHplane_0_60_100.dat
# Loaded plane HHplane_0_60_120.dat
# Loaded plane HHplane_0_60_140.dat
# Loaded plane HHplane_0_60_160.dat
# Loaded plane HHplane_0_60_180.dat
# Loaded plane HHplane_0_60_200.dat
# Loaded plane HHplane_0_60_220.dat
# Loaded plane HHplane_0_80_0.dat
# Loaded plane HHplane_0_80_20.dat
# Loaded plane HHplane_0_80_40.dat
# Loaded plane HHplane_0_80_60.dat
# Loaded plane HHplane_0_80_80.dat
# Loaded plane HHplane_0_80_100.dat
# Loaded plane HHplane_0_80_120.dat
# Loaded plane HHplane_0_80_140.dat
# Loaded plane HHplane_0_80_160.dat
# Loaded plane HHplane_0_80_180.dat
# Loaded plane HHplane_0_80_200.dat
# Loaded plane HHplane_0_80_220.dat
# Loaded plane HHplane_0_100_0.dat
# Loaded plane HHplane_0_100_20.dat
# Loaded plane HHplane_0_100_40.dat
# Loaded plane HHplane_0_100_60.dat
# Loaded plane HHplane_0_100_80.dat
# Loaded plane HHplane_0_100_100.dat
# Loaded plane HHplane_0_100_120.dat
# Loaded plane HHplane_0_100_140.dat
# Loaded plane HHplane_0_100_160.dat
# Loaded plane HHplane_0_100_180.dat
# Loaded plane HHplane_0_100_200.dat
# Loaded plane HHplane_0_100_220.dat
# Loaded plane HHplane_0_120_0.dat
# Loaded plane HHplane_0_120_20.dat
# Loaded plane HHplane_0_120_40.dat
# Loaded plane HHplane_0_120_60.dat
# Loaded plane HHplane_0_120_80.dat
# Loaded plane HHplane_0_120_100.dat
# Loaded plane HHplane_0_120_120.dat
# Loaded plane HHplane_0_120_140.dat
# Loaded plane HHplane_0_120_160.dat
# Loaded plane HHplane_0_120_180.dat
# Loaded plane HHplane_0_120_200.dat
# Loaded plane HHplane_0_120_220.dat
# Loaded plane HHplane_0_140_0.dat
# Loaded plane HHplane_0_140_20.dat
# Loaded plane HHplane_0_140_40.dat
# Loaded plane HHplane_0_140_60.dat
# Loaded plane HHplane_0_140_80.dat
# Loaded plane HHplane_0_140_100.dat
# Loaded plane HHplane_0_140_120.dat
# Loaded plane HHplane_0_140_140.dat
# Loaded plane HHplane_0_140_160.dat
# Loaded plane HHplane_0_140_180.dat
# Loaded plane HHplane_0_140_200.dat
# Loaded plane HHplane_0_140_220.dat
# Loaded plane HHplane_0_160_0.dat
# Loaded plane HHplane_0_160_20.dat
# Loaded plane HHplane_0_160_40.dat
# Loaded plane HHplane_0_160_60.dat
# Loaded plane HHplane_0_160_80.dat
# Loaded plane HHplane_0_160_100.dat
# Loaded plane HHplane_0_160_120.dat
# Loaded plane HHplane_0_160_140.dat
# Loaded plane HHplane_0_160_160.dat
# Loaded plane HHplane_0_160_180.dat
# Loaded plane HHplane_0_160_200.dat
# Loaded plane HHplane_0_160_220.dat
# Loaded plane HHplane_0_180_0.dat
# Loaded plane HHplane_0_180_20.dat
# Loaded plane HHplane_0_180_40.dat
# Loaded plane HHplane_0_180_60.dat
# Loaded plane HHplane_0_180_80.dat
# Loaded plane HHplane_0_180_100.dat
# Loaded plane HHplane_0_180_120.dat
# Loaded plane HHplane_0_180_140.dat
# Loaded plane HHplane_0_180_160.dat
# Loaded plane HHplane_0_180_180.dat
# Loaded plane HHplane_0_180_200.dat
# Loaded plane HHplane_0_180_220.dat
# Loaded plane HHplane_0_200_0.dat
# Loaded plane HHplane_0_200_20.dat
# Loaded plane HHplane_0_200_40.dat
# Loaded plane HHplane_0_200_60.dat
# Loaded plane HHplane_0_200_80.dat
# Loaded plane HHplane_0_200_100.dat
# Loaded plane HHplane_0_200_120.dat
# Loaded plane HHplane_0_200_140.dat
# Loaded plane HHplane_0_200_160.dat
# Loaded plane HHplane_0_200_180.dat
# Loaded plane HHplane_0_200_200.dat
# Loaded plane HHplane_0_200_220.dat
# Loaded plane HHplane_0_220_0.dat
# Loaded plane HHplane_0_220_20.dat
# Loaded plane HHplane_0_220_40.dat
# Loaded plane HHplane_0_220_60.dat
# Loaded plane HHplane_0_220_80.dat
# Loaded plane HHplane_0_220_100.dat
# Loaded plane HHplane_0_220_120.dat
# Loaded plane HHplane_0_220_140.dat
# Loaded plane HHplane_0_220_160.dat
# Loaded plane HHplane_0_220_180.dat
# Loaded plane HHplane_0_220_200.dat
# Loaded plane HHplane_0_220_220.dat
# Averaged over 144 planes

# %%
# Get the equivalent Kaimal spectra
#avgUlong = np.mean(all_ulongavgs)
s='20'
print("Avg Ulong = %f zavg = %f"%(avgUlong[s], zavg[s]))
Su_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s])
Sv_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s], params=windspectra.vKaimalconst)
Sw_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s], params=windspectra.wKaimalconst)

fmax = 0.6*avgUlong[s]/(8*np.sqrt(2)*10)
print("fmax = %f"%fmax)
print("nmax = %f"%(fmax*zavg[s]/utau))
# Out:
# Avg Ulong = 5.003028 zavg = 20.000000
# fmax = 0.026533
# nmax = 3.245574

# %%
# Plot the longitudinal spectral
plt.figure(figsize=(8,8))
plt.rc('font', size=14)
plt.rc('xtick', labelsize=14)
# Plot the Nalu Wind spectra
s='20'
f=favg[s]
plt.loglog(f, f*Suu_avg[s]/utau**2, 'b--', label='Nalu-Wind [u]')
plt.loglog(f, f*Svv_avg[s]/utau**2, 'r--', label='Nalu-Wind [v]')
plt.loglog(f, f*Sww_avg[s]/utau**2, 'g--', label='Nalu-Wind [w]')

# Plot Kaimal
plt.loglog(f, Su_Kai[s],'b', lw=3, label='Kaimal [u]')
plt.loglog(f, Sv_Kai[s],'r', lw=3, label='Kaimal [v]')
plt.loglog(f, Sw_Kai[s],'g', lw=3, label='Kaimal [w]')

# Plot where the spectral cut-off is
plt.vlines(fmax, 5e-2, 1.5,lw=3, linestyle='-.')

plt.vlines(0.0049*np.arange(1,4), 1e-1, 10, lw=1, linestyle='--')

# Formatting options
plt.ylim([2E-2, 6]);
plt.xlim([1E-4, 1]);
plt.xlabel('Frequency $f$ [Hz]')
plt.ylabel('$f\cdot S_{u,v,w}/u_{\\tau}^2$ [-]')
plt.title('Avg spectra [Unstable 10 m/s, z=%sm]'%s)
plt.legend(loc='upper left')

# %%
# --- Paper version ---
plt.figure(figsize=(5,5),dpi=100)
plt.rc('font', size=16)
plt.rc('xtick', labelsize=14)
# Plot the Nalu Wind spectra
s='20'
f=favg[s]
plt.loglog(f, f*Suu_avg[s]/utau**2, 'b--', label='Nalu-Wind [u]')
plt.loglog(f, f*Svv_avg[s]/utau**2, 'r--', label='Nalu-Wind [v]')
plt.loglog(f, f*Sww_avg[s]/utau**2, 'g--', label='Nalu-Wind [w]')

# Plot Kaimal
plt.loglog(f, Su_Kai[s],'b', lw=3, label='Kaimal [u]')
plt.loglog(f, Sv_Kai[s],'r', lw=3, label='Kaimal [v]')
plt.loglog(f, Sw_Kai[s],'g', lw=3, label='Kaimal [w]')

# Plot where the spectral cut-off is
plt.vlines(fmax, 5e-2, 1.5,lw=3, linestyle='-.')

# Formatting options
plt.ylim([2E-2, 3]);
plt.xlim([1E-4, 1]);
plt.xlabel('Frequency $f$ [Hz]')
plt.ylabel('$f\cdot S_{i}/u_{\\tau}^2$ [-]')
#plt.title('Avg spectra [Neutral 10 m/s, z=%sm]'%s)
#plt.legend(loc='upper left')

# %%
# --- just make a legend ---
legend_el = [Line2D([0],[0], linestyle='--', color='b', linewidth=2, label='Nalu-Wind [u]'),
             Line2D([0],[0], linestyle='--', color='r', linewidth=2, label='Nalu-Wind [v]'),
             Line2D([0],[0], linestyle='--', color='g', linewidth=2, label='Nalu-Wind [w]'),
             Line2D([0],[0], linestyle='-',  color='b', linewidth=3, label='Kaimal [u]'),
             Line2D([0],[0], linestyle='-',  color='r', linewidth=3, label='Kaimal [v]'),
             Line2D([0],[0], linestyle='-',  color='g', linewidth=3, label='Kaimal [w]'),
            ]
plt.figure(figsize=(3,1))
plt.legend(handles=legend_el, fontsize=16, frameon=False)
plt.axis('off')
plt.tight_layout()

# %%
# Define data locations and variables z=40m
datadir = '/ascldap/users/lcheung/nscratch/Torque2020/Runs/unstable/05ms/05ms_iter01/statsData/extractpoints/HHplane_plane1'
planeprefix = 'HHplane_'
planenum = 1
#jvector  = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54] 
#ivector  = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54] 
jvector  = range(0,221,20) # [0, 40, 80, 120, 160, 200] 
ivector  = range(0,221,20) # [0, 40, 80, 120, 160, 200] 

# Averaging bins
avgbins = [[14500.5, 18160.5], [16330.5,19990.5]]
#avgbins = [[25000.5, 26300], [25650.5, 26950]]

# Friction velocity.  Eventually this should be pulled from the ABL stats file
utau     = 0.1635

# %%
# Construct the list of planefiles and average
s='40'
planefiles=[]
for j in jvector:
    for i in ivector:
        planefiles.append(planeprefix+'%i_%i_%i.dat'%(planenum, j,i))
favg[s], Suu_avg[s], Svv_avg[s], Sww_avg[s], avgUlong[s], zavg[s] = avgSpectraPlanefiles(planefiles, verbose=True)
# Out:
# Loaded plane HHplane_1_0_0.dat
# Loaded plane HHplane_1_0_20.dat
# Loaded plane HHplane_1_0_40.dat
# Loaded plane HHplane_1_0_60.dat
# Loaded plane HHplane_1_0_80.dat
# Loaded plane HHplane_1_0_100.dat
# Loaded plane HHplane_1_0_120.dat
# Loaded plane HHplane_1_0_140.dat
# Loaded plane HHplane_1_0_160.dat
# Loaded plane HHplane_1_0_180.dat
# Loaded plane HHplane_1_0_200.dat
# Loaded plane HHplane_1_0_220.dat
# Loaded plane HHplane_1_20_0.dat
# Loaded plane HHplane_1_20_20.dat
# Loaded plane HHplane_1_20_40.dat
# Loaded plane HHplane_1_20_60.dat
# Loaded plane HHplane_1_20_80.dat
# Loaded plane HHplane_1_20_100.dat
# Loaded plane HHplane_1_20_120.dat
# Loaded plane HHplane_1_20_140.dat
# Loaded plane HHplane_1_20_160.dat
# Loaded plane HHplane_1_20_180.dat
# Loaded plane HHplane_1_20_200.dat
# Loaded plane HHplane_1_20_220.dat
# Loaded plane HHplane_1_40_0.dat
# Loaded plane HHplane_1_40_20.dat
# Loaded plane HHplane_1_40_40.dat
# Loaded plane HHplane_1_40_60.dat
# Loaded plane HHplane_1_40_80.dat
# Loaded plane HHplane_1_40_100.dat
# Loaded plane HHplane_1_40_120.dat
# Loaded plane HHplane_1_40_140.dat
# Loaded plane HHplane_1_40_160.dat
# Loaded plane HHplane_1_40_180.dat
# Loaded plane HHplane_1_40_200.dat
# Loaded plane HHplane_1_40_220.dat
# Loaded plane HHplane_1_60_0.dat
# Loaded plane HHplane_1_60_20.dat
# Loaded plane HHplane_1_60_40.dat
# Loaded plane HHplane_1_60_60.dat
# Loaded plane HHplane_1_60_80.dat
# Loaded plane HHplane_1_60_100.dat
# Loaded plane HHplane_1_60_120.dat
# Loaded plane HHplane_1_60_140.dat
# Loaded plane HHplane_1_60_160.dat
# Loaded plane HHplane_1_60_180.dat
# Loaded plane HHplane_1_60_200.dat
# Loaded plane HHplane_1_60_220.dat
# Loaded plane HHplane_1_80_0.dat
# Loaded plane HHplane_1_80_20.dat
# Loaded plane HHplane_1_80_40.dat
# Loaded plane HHplane_1_80_60.dat
# Loaded plane HHplane_1_80_80.dat
# Loaded plane HHplane_1_80_100.dat
# Loaded plane HHplane_1_80_120.dat
# Loaded plane HHplane_1_80_140.dat
# Loaded plane HHplane_1_80_160.dat
# Loaded plane HHplane_1_80_180.dat
# Loaded plane HHplane_1_80_200.dat
# Loaded plane HHplane_1_80_220.dat
# Loaded plane HHplane_1_100_0.dat
# Loaded plane HHplane_1_100_20.dat
# Loaded plane HHplane_1_100_40.dat
# Loaded plane HHplane_1_100_60.dat
# Loaded plane HHplane_1_100_80.dat
# Loaded plane HHplane_1_100_100.dat
# Loaded plane HHplane_1_100_120.dat
# Loaded plane HHplane_1_100_140.dat
# Loaded plane HHplane_1_100_160.dat
# Loaded plane HHplane_1_100_180.dat
# Loaded plane HHplane_1_100_200.dat
# Loaded plane HHplane_1_100_220.dat
# Loaded plane HHplane_1_120_0.dat
# Loaded plane HHplane_1_120_20.dat
# Loaded plane HHplane_1_120_40.dat
# Loaded plane HHplane_1_120_60.dat
# Loaded plane HHplane_1_120_80.dat
# Loaded plane HHplane_1_120_100.dat
# Loaded plane HHplane_1_120_120.dat
# Loaded plane HHplane_1_120_140.dat
# Loaded plane HHplane_1_120_160.dat
# Loaded plane HHplane_1_120_180.dat
# Loaded plane HHplane_1_120_200.dat
# Loaded plane HHplane_1_120_220.dat
# Loaded plane HHplane_1_140_0.dat
# Loaded plane HHplane_1_140_20.dat
# Loaded plane HHplane_1_140_40.dat
# Loaded plane HHplane_1_140_60.dat
# Loaded plane HHplane_1_140_80.dat
# Loaded plane HHplane_1_140_100.dat
# Loaded plane HHplane_1_140_120.dat
# Loaded plane HHplane_1_140_140.dat
# Loaded plane HHplane_1_140_160.dat
# Loaded plane HHplane_1_140_180.dat
# Loaded plane HHplane_1_140_200.dat
# Loaded plane HHplane_1_140_220.dat
# Loaded plane HHplane_1_160_0.dat
# Loaded plane HHplane_1_160_20.dat
# Loaded plane HHplane_1_160_40.dat
# Loaded plane HHplane_1_160_60.dat
# Loaded plane HHplane_1_160_80.dat
# Loaded plane HHplane_1_160_100.dat
# Loaded plane HHplane_1_160_120.dat
# Loaded plane HHplane_1_160_140.dat
# Loaded plane HHplane_1_160_160.dat
# Loaded plane HHplane_1_160_180.dat
# Loaded plane HHplane_1_160_200.dat
# Loaded plane HHplane_1_160_220.dat
# Loaded plane HHplane_1_180_0.dat
# Loaded plane HHplane_1_180_20.dat
# Loaded plane HHplane_1_180_40.dat
# Loaded plane HHplane_1_180_60.dat
# Loaded plane HHplane_1_180_80.dat
# Loaded plane HHplane_1_180_100.dat
# Loaded plane HHplane_1_180_120.dat
# Loaded plane HHplane_1_180_140.dat
# Loaded plane HHplane_1_180_160.dat
# Loaded plane HHplane_1_180_180.dat
# Loaded plane HHplane_1_180_200.dat
# Loaded plane HHplane_1_180_220.dat
# Loaded plane HHplane_1_200_0.dat
# Loaded plane HHplane_1_200_20.dat
# Loaded plane HHplane_1_200_40.dat
# Loaded plane HHplane_1_200_60.dat
# Loaded plane HHplane_1_200_80.dat
# Loaded plane HHplane_1_200_100.dat
# Loaded plane HHplane_1_200_120.dat
# Loaded plane HHplane_1_200_140.dat
# Loaded plane HHplane_1_200_160.dat
# Loaded plane HHplane_1_200_180.dat
# Loaded plane HHplane_1_200_200.dat
# Loaded plane HHplane_1_200_220.dat
# Loaded plane HHplane_1_220_0.dat
# Loaded plane HHplane_1_220_20.dat
# Loaded plane HHplane_1_220_40.dat
# Loaded plane HHplane_1_220_60.dat
# Loaded plane HHplane_1_220_80.dat
# Loaded plane HHplane_1_220_100.dat
# Loaded plane HHplane_1_220_120.dat
# Loaded plane HHplane_1_220_140.dat
# Loaded plane HHplane_1_220_160.dat
# Loaded plane HHplane_1_220_180.dat
# Loaded plane HHplane_1_220_200.dat
# Loaded plane HHplane_1_220_220.dat
# Averaged over 144 planes

# %%
# Get the equivalent Kaimal spectra
#avgUlong = np.mean(all_ulongavgs)
s='40'
print("Avg Ulong = %f zavg = %f"%(avgUlong[s], zavg[s]))
Su_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s])
Sv_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s], params=windspectra.vKaimalconst)
Sw_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s], params=windspectra.wKaimalconst)

fmax = 0.6*avgUlong[s]/(8*np.sqrt(2)*10)
print("fmax = %f"%fmax)
print("nmax = %f"%(fmax*zavg[s]/utau))
# Out:
# Avg Ulong = 5.088434 zavg = 40.000000
# fmax = 0.026985
# nmax = 6.601957

# %%
# Plot the longitudinal spectral
plt.figure(figsize=(8,8))
plt.rc('font', size=14)
plt.rc('xtick', labelsize=14)
# Plot the Nalu Wind spectra
s='40'
f=favg[s]
plt.loglog(f, f*Suu_avg[s]/utau**2, 'b--', label='Nalu-Wind [u]')
plt.loglog(f, f*Svv_avg[s]/utau**2, 'r--', label='Nalu-Wind [v]')
plt.loglog(f, f*Sww_avg[s]/utau**2, 'g--', label='Nalu-Wind [w]')

# Plot Kaimal
plt.loglog(f, Su_Kai[s],'b', lw=3, label='Kaimal [u]')
plt.loglog(f, Sv_Kai[s],'r', lw=3, label='Kaimal [v]')
plt.loglog(f, Sw_Kai[s],'g', lw=3, label='Kaimal [w]')

# Plot where the spectral cut-off is
plt.vlines(fmax, 5e-2, 1.5,lw=3, linestyle='-.')
#plt.vlines(0.0049*np.arange(1,4), 1e-1, 10, lw=1, linestyle='--')

# Formatting options
plt.ylim([2E-2, 6]);
plt.xlim([1E-4, 1]);
plt.xlabel('Frequency $f$ [Hz]')
plt.ylabel('$f\cdot S_{u,v,w}/u_{\\tau}^2$ [-]')
plt.title('Avg spectra [Unstable 10 m/s, z=%sm]'%s)
plt.legend(loc='upper left')

# %%
# Define data locations and variables z=40m
datadir = '/ascldap/users/lcheung/nscratch/Torque2020/Runs/unstable/05ms/05ms_iter01/statsData/extractpoints/HHplane_plane2'
planeprefix = 'HHplane_'
planenum = 2
#jvector  = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54] 
#ivector  = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54] 
jvector  = range(0,221,20) # [0, 40, 80, 120, 160, 200] 
ivector  = range(0,221,20) # [0, 40, 80, 120, 160, 200] 

# Averaging bins
avgbins = [[14500.5, 18160.5], [16330.5,19990.5]]
#avgbins = [[25000.5, 26300], [25650.5, 26950]]

# Friction velocity.  Eventually this should be pulled from the ABL stats file
utau     = 0.1635

# %%
# Construct the list of planefiles and average
s='60'
planefiles=[]
for j in jvector:
    for i in ivector:
        planefiles.append(planeprefix+'%i_%i_%i.dat'%(planenum, j,i))
favg[s], Suu_avg[s], Svv_avg[s], Sww_avg[s], avgUlong[s], zavg[s] = avgSpectraPlanefiles(planefiles, verbose=True)
# Out:
# Loaded plane HHplane_2_0_0.dat
# Loaded plane HHplane_2_0_20.dat
# Loaded plane HHplane_2_0_40.dat
# Loaded plane HHplane_2_0_60.dat
# Loaded plane HHplane_2_0_80.dat
# Loaded plane HHplane_2_0_100.dat
# Loaded plane HHplane_2_0_120.dat
# Loaded plane HHplane_2_0_140.dat
# Loaded plane HHplane_2_0_160.dat
# Loaded plane HHplane_2_0_180.dat
# Loaded plane HHplane_2_0_200.dat
# Loaded plane HHplane_2_0_220.dat
# Loaded plane HHplane_2_20_0.dat
# Loaded plane HHplane_2_20_20.dat
# Loaded plane HHplane_2_20_40.dat
# Loaded plane HHplane_2_20_60.dat
# Loaded plane HHplane_2_20_80.dat
# Loaded plane HHplane_2_20_100.dat
# Loaded plane HHplane_2_20_120.dat
# Loaded plane HHplane_2_20_140.dat
# Loaded plane HHplane_2_20_160.dat
# Loaded plane HHplane_2_20_180.dat
# Loaded plane HHplane_2_20_200.dat
# Loaded plane HHplane_2_20_220.dat
# Loaded plane HHplane_2_40_0.dat
# Loaded plane HHplane_2_40_20.dat
# Loaded plane HHplane_2_40_40.dat
# Loaded plane HHplane_2_40_60.dat
# Loaded plane HHplane_2_40_80.dat
# Loaded plane HHplane_2_40_100.dat
# Loaded plane HHplane_2_40_120.dat
# Loaded plane HHplane_2_40_140.dat
# Loaded plane HHplane_2_40_160.dat
# Loaded plane HHplane_2_40_180.dat
# Loaded plane HHplane_2_40_200.dat
# Loaded plane HHplane_2_40_220.dat
# Loaded plane HHplane_2_60_0.dat
# Loaded plane HHplane_2_60_20.dat
# Loaded plane HHplane_2_60_40.dat
# Loaded plane HHplane_2_60_60.dat
# Loaded plane HHplane_2_60_80.dat
# Loaded plane HHplane_2_60_100.dat
# Loaded plane HHplane_2_60_120.dat
# Loaded plane HHplane_2_60_140.dat
# Loaded plane HHplane_2_60_160.dat
# Loaded plane HHplane_2_60_180.dat
# Loaded plane HHplane_2_60_200.dat
# Loaded plane HHplane_2_60_220.dat
# Loaded plane HHplane_2_80_0.dat
# Loaded plane HHplane_2_80_20.dat
# Loaded plane HHplane_2_80_40.dat
# Loaded plane HHplane_2_80_60.dat
# Loaded plane HHplane_2_80_80.dat
# Loaded plane HHplane_2_80_100.dat
# Loaded plane HHplane_2_80_120.dat
# Loaded plane HHplane_2_80_140.dat
# Loaded plane HHplane_2_80_160.dat
# Loaded plane HHplane_2_80_180.dat
# Loaded plane HHplane_2_80_200.dat
# Loaded plane HHplane_2_80_220.dat
# Loaded plane HHplane_2_100_0.dat
# Loaded plane HHplane_2_100_20.dat
# Loaded plane HHplane_2_100_40.dat
# Loaded plane HHplane_2_100_60.dat
# Loaded plane HHplane_2_100_80.dat
# Loaded plane HHplane_2_100_100.dat
# Loaded plane HHplane_2_100_120.dat
# Loaded plane HHplane_2_100_140.dat
# Loaded plane HHplane_2_100_160.dat
# Loaded plane HHplane_2_100_180.dat
# Loaded plane HHplane_2_100_200.dat
# Loaded plane HHplane_2_100_220.dat
# Loaded plane HHplane_2_120_0.dat
# Loaded plane HHplane_2_120_20.dat
# Loaded plane HHplane_2_120_40.dat
# Loaded plane HHplane_2_120_60.dat
# Loaded plane HHplane_2_120_80.dat
# Loaded plane HHplane_2_120_100.dat
# Loaded plane HHplane_2_120_120.dat
# Loaded plane HHplane_2_120_140.dat
# Loaded plane HHplane_2_120_160.dat
# Loaded plane HHplane_2_120_180.dat
# Loaded plane HHplane_2_120_200.dat
# Loaded plane HHplane_2_120_220.dat
# Loaded plane HHplane_2_140_0.dat
# Loaded plane HHplane_2_140_20.dat
# Loaded plane HHplane_2_140_40.dat
# Loaded plane HHplane_2_140_60.dat
# Loaded plane HHplane_2_140_80.dat
# Loaded plane HHplane_2_140_100.dat
# Loaded plane HHplane_2_140_120.dat
# Loaded plane HHplane_2_140_140.dat
# Loaded plane HHplane_2_140_160.dat
# Loaded plane HHplane_2_140_180.dat
# Loaded plane HHplane_2_140_200.dat
# Loaded plane HHplane_2_140_220.dat
# Loaded plane HHplane_2_160_0.dat
# Loaded plane HHplane_2_160_20.dat
# Loaded plane HHplane_2_160_40.dat
# Loaded plane HHplane_2_160_60.dat
# Loaded plane HHplane_2_160_80.dat
# Loaded plane HHplane_2_160_100.dat
# Loaded plane HHplane_2_160_120.dat
# Loaded plane HHplane_2_160_140.dat
# Loaded plane HHplane_2_160_160.dat
# Loaded plane HHplane_2_160_180.dat
# Loaded plane HHplane_2_160_200.dat
# Loaded plane HHplane_2_160_220.dat
# Loaded plane HHplane_2_180_0.dat
# Loaded plane HHplane_2_180_20.dat
# Loaded plane HHplane_2_180_40.dat
# Loaded plane HHplane_2_180_60.dat
# Loaded plane HHplane_2_180_80.dat
# Loaded plane HHplane_2_180_100.dat
# Loaded plane HHplane_2_180_120.dat
# Loaded plane HHplane_2_180_140.dat
# Loaded plane HHplane_2_180_160.dat
# Loaded plane HHplane_2_180_180.dat
# Loaded plane HHplane_2_180_200.dat
# Loaded plane HHplane_2_180_220.dat
# Loaded plane HHplane_2_200_0.dat
# Loaded plane HHplane_2_200_20.dat
# Loaded plane HHplane_2_200_40.dat
# Loaded plane HHplane_2_200_60.dat
# Loaded plane HHplane_2_200_80.dat
# Loaded plane HHplane_2_200_100.dat
# Loaded plane HHplane_2_200_120.dat
# Loaded plane HHplane_2_200_140.dat
# Loaded plane HHplane_2_200_160.dat
# Loaded plane HHplane_2_200_180.dat
# Loaded plane HHplane_2_200_200.dat
# Loaded plane HHplane_2_200_220.dat
# Loaded plane HHplane_2_220_0.dat
# Loaded plane HHplane_2_220_20.dat
# Loaded plane HHplane_2_220_40.dat
# Loaded plane HHplane_2_220_60.dat
# Loaded plane HHplane_2_220_80.dat
# Loaded plane HHplane_2_220_100.dat
# Loaded plane HHplane_2_220_120.dat
# Loaded plane HHplane_2_220_140.dat
# Loaded plane HHplane_2_220_160.dat
# Loaded plane HHplane_2_220_180.dat
# Loaded plane HHplane_2_220_200.dat
# Loaded plane HHplane_2_220_220.dat
# Averaged over 144 planes

# %%
# Get the equivalent Kaimal spectra
s='60'
print("Avg Ulong = %f zavg = %f"%(avgUlong[s], zavg[s]))
Su_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s])
Sv_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s], params=windspectra.vKaimalconst)
Sw_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s], params=windspectra.wKaimalconst)

fmax = 0.6*avgUlong[s]/(8*np.sqrt(2)*10)
print("fmax = %f"%fmax)
print("nmax = %f"%(fmax*zavg[s]/utau))
# Out:
# Avg Ulong = 5.130672 zavg = 60.000000
# fmax = 0.027209
# nmax = 9.985137

# %%
# Plot the longitudinal spectral
plt.figure(figsize=(8,8))
plt.rc('font', size=14)
plt.rc('xtick', labelsize=14)
# Plot the Nalu Wind spectra
s='60'
f=favg[s]
plt.loglog(f, f*Suu_avg[s]/utau**2, 'b--', label='Nalu-Wind [u]')
plt.loglog(f, f*Svv_avg[s]/utau**2, 'r--', label='Nalu-Wind [v]')
plt.loglog(f, f*Sww_avg[s]/utau**2, 'g--', label='Nalu-Wind [w]')

# Plot Kaimal
plt.loglog(f, Su_Kai[s],'b', lw=3, label='Kaimal [u]')
plt.loglog(f, Sv_Kai[s],'r', lw=3, label='Kaimal [v]')
plt.loglog(f, Sw_Kai[s],'g', lw=3, label='Kaimal [w]')

# Plot where the spectral cut-off is
plt.vlines(fmax, 5e-2, 1.5,lw=3, linestyle='-.')
#plt.vlines(0.0049*np.arange(1,4), 1e-1, 10, lw=1, linestyle='--')

# Formatting options
plt.ylim([2E-2, 6]);
plt.xlim([1E-4, 1]);
plt.xlabel('Frequency $f$ [Hz]')
plt.ylabel('$f\cdot S_{u,v,w}/u_{\\tau}^2$ [-]')
plt.title('Avg spectra [Unstable 10 m/s, z=%sm]'%s)
plt.legend(loc='upper left')

# %%
plt.figure(figsize=(5,5),dpi=100)
#Su_Kai20 = windspectra.getKaimal(favg, 20, 5.0)
#Su_Kai40 = windspectra.getKaimal(favg/3, 40, 5.2)
#plt.loglog(favg*20/5.00, favg*Suu_avg20/utau**2,'b--', lw=1, label='Kaimal [20]')
#plt.loglog(favg*40/5.28, favg*Suu_avg40/utau**2,'k--', lw=1, label='Kaimal [40]')
#plt.loglog(favg*20/5.00, Su_Kai20,'b', lw=3, label='Kaimal [20]')
#plt.loglog(favg*40/5.28, Su_Kai40,'k', lw=3, label='Kaimal [40]')

plt.loglog(favg['20'], Su_Kai['20'],  color='gray',  lw=4, label='Kaimal z=20')
#plt.loglog(favg['40'], Su_Kai['40'],  'k', lw=3, label='Kaimal [40]')
#plt.loglog(favg['60'], Su_Kai['60'],  'r', lw=3, label='Kaimal [60]')

plt.loglog(favg['20'], favg['20']*Suu_avg['20']/utau**2,'-',   color='blue', lw=2, label='z=20')
plt.loglog(favg['40'], favg['40']*Suu_avg['40']/utau**2, '--', color='blue', lw=1, label='z=40')
plt.loglog(favg['60'], favg['60']*Suu_avg['60']/utau**2,'-.',  color='blue', lw=0.5, label='z=60')

# Formatting options
#plt.legend(fontsize=12, frameon=False)
plt.ylim([2E-2, 3]);
plt.title('5m/s unstable $S_u(f)$')
plt.xlabel('Frequency $f$ [Hz]')
plt.ylabel('$f\cdot S_{i}/u_{\\tau}^2$ [-]')
