# %% [markdown]
# # Nalu-Wind Spectra 2.5x2.5x2.5m case
# ## This is with the large CFL run

# %%
# %%capture

import sys
naluhelperdir = '../../../../Postprocessing/utilities/'
sys.path.insert(1, naluhelperdir)

# Change some display properties
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
import matplotlib.pyplot as plt
import numpy as np
import windspectra
import os.path
from matplotlib.lines import Line2D
# %matplotlib inline

# %%
# Average the spectra over multiple locations
# given by locations in planefilelist
def avgSpectraPlanefiles(planefilelist, verbose=True):
    # set initial values
    iplane = 0
    all_ulongavgs = []
    lent = 0
    # Loop through and get spectra
    for planefile in planefilelist:
        if not os.path.isfile(datadir+'/'+planefile): continue
        dat       = np.loadtxt(datadir+'/'+planefile)
        t   = dat[:,0]
        z   = dat[:,6]
        u   = dat[:,7]
        v   = dat[:,8]
        w   = dat[:,9]
        if ((iplane != 0) and (lent != len(t))): continue
        if verbose: print("Loaded plane "+planefile)
        ulong, ulat = windspectra.convertUxytoLongLat(u,v)
        all_ulongavgs.append(np.mean(ulong))
        f, Suu      = windspectra.avgWindSpectra(t, ulong, avgbins)
        f, Svv      = windspectra.avgWindSpectra(t, ulat,  avgbins)
        f, Sww      = windspectra.avgWindSpectra(t, w,     avgbins)
        if iplane == 0:
            lent    = len(t)
            favg    = f
            Suu_avg = Suu
            Svv_avg = Svv
            Sww_avg = Sww
        else:
            Suu_avg = Suu_avg + Suu
            Svv_avg = Svv_avg + Svv
            Sww_avg = Sww_avg + Sww
        iplane = iplane+1
        zavg   = np.mean(z)
    # Average the spectra
    Suu_avg = Suu_avg/iplane
    Svv_avg = Svv_avg/iplane
    Sww_avg = Sww_avg/iplane
    if verbose: print("Averaged over %i planes"%iplane)
    return favg, Suu_avg, Svv_avg, Sww_avg, np.mean(all_ulongavgs), zavg

# %%
# Define some dicts to save stuff
Suu_avg={}
Svv_avg={}
Sww_avg={}
avgUlong={}
zavg={}
favg={}
allfmax={}
Su_Kai={}
Sv_Kai={}
Sw_Kai={}

# %%
# Define data locations and variables
#datadir  = '/ascldap/users/lcheung/nscratch/Torque2020/Runs/stable/05ms/mini05_iter05/statsData/extractpoints/HHplane_plane0'
#datadir = '/ascldap/users/lcheung/nscratch/Torque2020/Runs/stable/05ms/mini05_iter18/extractpoints/HHplane_plane0'
#datadir     = './spectra/HHplane_plane0.short/'
datadirs    = ['./spectra/HHplane_plane0/',
               './spectra/HHplane_plane1/',
               './spectra/HHplane_plane2/',
              ]
planeprefix = 'HHplane_'
#planenum = 0
ivector  = np.linspace(0,400,41)
jvector  = np.linspace(0,400,41)
#jvector  = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75] 
#ivector  = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75] 

szvector = [[0, '20'],  
            [1, '40'], 
            [2, '60'],
           ]

# Averaging bins
avgbins = [[15000.5, 18300],[16650.5, 19950]] #[[20000.5, 23300],[21650.5, 24950]]

# Friction velocity.  Eventually this should be pulled from the ABL stats file
#utau     = 0.15586776602361152 #0.14238698987034834
utau    = 0.16334234874262635

dx          = 2.5 # Grid spacing
saveprefix  ='NaluWind_Stable05_spectra_dx%04.1f'%dx

# %%
# Construct the list of planefiles and average
#s='20'
for izrow, zrow in enumerate(szvector):
    zpt = zrow[0]
    s   = zrow[1]
    datadir = datadirs[izrow]
    planefiles=[]
    for j in jvector:
        for i in ivector:
            planefiles.append(planeprefix+'%i_%i_%i.dat'%(zpt, j,i))
    favg[s], Suu_avg[s], Svv_avg[s], Sww_avg[s], avgUlong[s], zavg[s] = avgSpectraPlanefiles(planefiles, verbose=True)
# Out:
# Loaded plane HHplane_0_0_0.dat
# Loaded plane HHplane_0_0_40.dat
# Loaded plane HHplane_0_0_80.dat
# Loaded plane HHplane_0_0_120.dat
# Loaded plane HHplane_0_0_160.dat
# Loaded plane HHplane_0_0_200.dat
# Loaded plane HHplane_0_0_240.dat
# Loaded plane HHplane_0_0_280.dat
# Loaded plane HHplane_0_0_320.dat
# Loaded plane HHplane_0_0_360.dat
# Loaded plane HHplane_0_0_400.dat
# Loaded plane HHplane_0_40_0.dat
# Loaded plane HHplane_0_40_40.dat
# Loaded plane HHplane_0_40_80.dat
# Loaded plane HHplane_0_40_120.dat
# Loaded plane HHplane_0_40_160.dat
# Loaded plane HHplane_0_40_200.dat
# Loaded plane HHplane_0_40_240.dat
# Loaded plane HHplane_0_40_280.dat
# Loaded plane HHplane_0_40_320.dat
# Loaded plane HHplane_0_40_360.dat
# Loaded plane HHplane_0_40_400.dat
# Loaded plane HHplane_0_80_0.dat
# Loaded plane HHplane_0_80_40.dat
# Loaded plane HHplane_0_80_80.dat
# Loaded plane HHplane_0_80_120.dat
# Loaded plane HHplane_0_80_160.dat
# Loaded plane HHplane_0_80_200.dat
# Loaded plane HHplane_0_80_240.dat
# Loaded plane HHplane_0_80_280.dat
# Loaded plane HHplane_0_80_320.dat
# Loaded plane HHplane_0_80_360.dat
# Loaded plane HHplane_0_80_400.dat
# Loaded plane HHplane_0_120_0.dat
# Loaded plane HHplane_0_120_40.dat
# Loaded plane HHplane_0_120_80.dat
# Loaded plane HHplane_0_120_120.dat
# Loaded plane HHplane_0_120_160.dat
# Loaded plane HHplane_0_120_200.dat
# Loaded plane HHplane_0_120_240.dat
# Loaded plane HHplane_0_120_280.dat
# Loaded plane HHplane_0_120_320.dat
# Loaded plane HHplane_0_120_360.dat
# Loaded plane HHplane_0_120_400.dat
# Loaded plane HHplane_0_160_0.dat
# Loaded plane HHplane_0_160_40.dat
# Loaded plane HHplane_0_160_80.dat
# Loaded plane HHplane_0_160_120.dat
# Loaded plane HHplane_0_160_160.dat
# Loaded plane HHplane_0_160_200.dat
# Loaded plane HHplane_0_160_240.dat
# Loaded plane HHplane_0_160_280.dat
# Loaded plane HHplane_0_160_320.dat
# Loaded plane HHplane_0_160_360.dat
# Loaded plane HHplane_0_160_400.dat
# Loaded plane HHplane_0_200_0.dat
# Loaded plane HHplane_0_200_40.dat
# Loaded plane HHplane_0_200_80.dat
# Loaded plane HHplane_0_200_120.dat
# Loaded plane HHplane_0_200_160.dat
# Loaded plane HHplane_0_200_200.dat
# Loaded plane HHplane_0_200_240.dat
# Loaded plane HHplane_0_200_280.dat
# Loaded plane HHplane_0_200_320.dat
# Loaded plane HHplane_0_200_360.dat
# Loaded plane HHplane_0_200_400.dat
# Loaded plane HHplane_0_240_0.dat
# Loaded plane HHplane_0_240_40.dat
# Loaded plane HHplane_0_240_80.dat
# Loaded plane HHplane_0_240_120.dat
# Loaded plane HHplane_0_240_160.dat
# Loaded plane HHplane_0_240_200.dat
# Loaded plane HHplane_0_240_240.dat
# Loaded plane HHplane_0_240_280.dat
# Loaded plane HHplane_0_240_320.dat
# Loaded plane HHplane_0_240_360.dat
# Loaded plane HHplane_0_240_400.dat
# Loaded plane HHplane_0_280_0.dat
# Loaded plane HHplane_0_280_40.dat
# Loaded plane HHplane_0_280_80.dat
# Loaded plane HHplane_0_280_120.dat
# Loaded plane HHplane_0_280_160.dat
# Loaded plane HHplane_0_280_200.dat
# Loaded plane HHplane_0_280_240.dat
# Loaded plane HHplane_0_280_280.dat
# Loaded plane HHplane_0_280_320.dat
# Loaded plane HHplane_0_280_360.dat
# Loaded plane HHplane_0_280_400.dat
# Loaded plane HHplane_0_320_0.dat
# Loaded plane HHplane_0_320_40.dat
# Loaded plane HHplane_0_320_80.dat
# Loaded plane HHplane_0_320_120.dat
# Loaded plane HHplane_0_320_160.dat
# Loaded plane HHplane_0_320_200.dat
# Loaded plane HHplane_0_320_240.dat
# Loaded plane HHplane_0_320_280.dat
# Loaded plane HHplane_0_320_320.dat
# Loaded plane HHplane_0_320_360.dat
# Loaded plane HHplane_0_320_400.dat
# Loaded plane HHplane_0_360_0.dat
# Loaded plane HHplane_0_360_40.dat
# Loaded plane HHplane_0_360_80.dat
# Loaded plane HHplane_0_360_120.dat
# Loaded plane HHplane_0_360_160.dat
# Loaded plane HHplane_0_360_200.dat
# Loaded plane HHplane_0_360_240.dat
# Loaded plane HHplane_0_360_280.dat
# Loaded plane HHplane_0_360_320.dat
# Loaded plane HHplane_0_360_360.dat
# Loaded plane HHplane_0_360_400.dat
# Loaded plane HHplane_0_400_0.dat
# Loaded plane HHplane_0_400_40.dat
# Loaded plane HHplane_0_400_80.dat
# Loaded plane HHplane_0_400_120.dat
# Loaded plane HHplane_0_400_160.dat
# Loaded plane HHplane_0_400_200.dat
# Loaded plane HHplane_0_400_240.dat
# Loaded plane HHplane_0_400_280.dat
# Loaded plane HHplane_0_400_320.dat
# Loaded plane HHplane_0_400_360.dat
# Loaded plane HHplane_0_400_400.dat
# Averaged over 121 planes
# Loaded plane HHplane_1_0_0.dat
# Loaded plane HHplane_1_0_40.dat
# Loaded plane HHplane_1_0_80.dat
# Loaded plane HHplane_1_0_120.dat
# Loaded plane HHplane_1_0_160.dat
# Loaded plane HHplane_1_0_200.dat
# Loaded plane HHplane_1_0_240.dat
# Loaded plane HHplane_1_0_280.dat
# Loaded plane HHplane_1_0_320.dat
# Loaded plane HHplane_1_0_360.dat
# Loaded plane HHplane_1_0_400.dat
# Loaded plane HHplane_1_40_0.dat
# Loaded plane HHplane_1_40_40.dat
# Loaded plane HHplane_1_40_80.dat
# Loaded plane HHplane_1_40_120.dat
# Loaded plane HHplane_1_40_160.dat
# Loaded plane HHplane_1_40_200.dat
# Loaded plane HHplane_1_40_240.dat
# Loaded plane HHplane_1_40_280.dat
# Loaded plane HHplane_1_40_320.dat
# Loaded plane HHplane_1_40_360.dat
# Loaded plane HHplane_1_40_400.dat
# Loaded plane HHplane_1_80_0.dat
# Loaded plane HHplane_1_80_40.dat
# Loaded plane HHplane_1_80_80.dat
# Loaded plane HHplane_1_80_120.dat
# Loaded plane HHplane_1_80_160.dat
# Loaded plane HHplane_1_80_200.dat
# Loaded plane HHplane_1_80_240.dat
# Loaded plane HHplane_1_80_280.dat
# Loaded plane HHplane_1_80_320.dat
# Loaded plane HHplane_1_80_360.dat
# Loaded plane HHplane_1_80_400.dat
# Loaded plane HHplane_1_120_0.dat
# Loaded plane HHplane_1_120_40.dat
# Loaded plane HHplane_1_120_80.dat
# Loaded plane HHplane_1_120_120.dat
# Loaded plane HHplane_1_120_160.dat
# Loaded plane HHplane_1_120_200.dat
# Loaded plane HHplane_1_120_240.dat
# Loaded plane HHplane_1_120_280.dat
# Loaded plane HHplane_1_120_320.dat
# Loaded plane HHplane_1_120_360.dat
# Loaded plane HHplane_1_120_400.dat
# Loaded plane HHplane_1_160_0.dat
# Loaded plane HHplane_1_160_40.dat
# Loaded plane HHplane_1_160_80.dat
# Loaded plane HHplane_1_160_120.dat
# Loaded plane HHplane_1_160_160.dat
# Loaded plane HHplane_1_160_200.dat
# Loaded plane HHplane_1_160_240.dat
# Loaded plane HHplane_1_160_280.dat
# Loaded plane HHplane_1_160_320.dat
# Loaded plane HHplane_1_160_360.dat
# Loaded plane HHplane_1_160_400.dat
# Loaded plane HHplane_1_200_0.dat
# Loaded plane HHplane_1_200_40.dat
# Loaded plane HHplane_1_200_80.dat
# Loaded plane HHplane_1_200_120.dat
# Loaded plane HHplane_1_200_160.dat
# Loaded plane HHplane_1_200_200.dat
# Loaded plane HHplane_1_200_240.dat
# Loaded plane HHplane_1_200_280.dat
# Loaded plane HHplane_1_200_320.dat
# Loaded plane HHplane_1_200_360.dat
# Loaded plane HHplane_1_200_400.dat
# Loaded plane HHplane_1_240_0.dat
# Loaded plane HHplane_1_240_40.dat
# Loaded plane HHplane_1_240_80.dat
# Loaded plane HHplane_1_240_120.dat
# Loaded plane HHplane_1_240_160.dat
# Loaded plane HHplane_1_240_200.dat
# Loaded plane HHplane_1_240_240.dat
# Loaded plane HHplane_1_240_280.dat
# Loaded plane HHplane_1_240_320.dat
# Loaded plane HHplane_1_240_360.dat
# Loaded plane HHplane_1_240_400.dat
# Loaded plane HHplane_1_280_0.dat
# Loaded plane HHplane_1_280_40.dat
# Loaded plane HHplane_1_280_80.dat
# Loaded plane HHplane_1_280_120.dat
# Loaded plane HHplane_1_280_160.dat
# Loaded plane HHplane_1_280_200.dat
# Loaded plane HHplane_1_280_240.dat
# Loaded plane HHplane_1_280_280.dat
# Loaded plane HHplane_1_280_320.dat
# Loaded plane HHplane_1_280_360.dat
# Loaded plane HHplane_1_280_400.dat
# Loaded plane HHplane_1_320_0.dat
# Loaded plane HHplane_1_320_40.dat
# Loaded plane HHplane_1_320_80.dat
# Loaded plane HHplane_1_320_120.dat
# Loaded plane HHplane_1_320_160.dat
# Loaded plane HHplane_1_320_200.dat
# Loaded plane HHplane_1_320_240.dat
# Loaded plane HHplane_1_320_280.dat
# Loaded plane HHplane_1_320_320.dat
# Loaded plane HHplane_1_320_360.dat
# Loaded plane HHplane_1_320_400.dat
# Loaded plane HHplane_1_360_0.dat
# Loaded plane HHplane_1_360_40.dat
# Loaded plane HHplane_1_360_80.dat
# Loaded plane HHplane_1_360_120.dat
# Loaded plane HHplane_1_360_160.dat
# Loaded plane HHplane_1_360_200.dat
# Loaded plane HHplane_1_360_240.dat
# Loaded plane HHplane_1_360_280.dat
# Loaded plane HHplane_1_360_320.dat
# Loaded plane HHplane_1_360_360.dat
# Loaded plane HHplane_1_360_400.dat
# Loaded plane HHplane_1_400_0.dat
# Loaded plane HHplane_1_400_40.dat
# Loaded plane HHplane_1_400_80.dat
# Loaded plane HHplane_1_400_120.dat
# Loaded plane HHplane_1_400_160.dat
# Loaded plane HHplane_1_400_200.dat
# Loaded plane HHplane_1_400_240.dat
# Loaded plane HHplane_1_400_280.dat
# Loaded plane HHplane_1_400_320.dat
# Loaded plane HHplane_1_400_360.dat
# Loaded plane HHplane_1_400_400.dat
# Averaged over 121 planes
# Loaded plane HHplane_2_0_0.dat
# Loaded plane HHplane_2_0_40.dat
# Loaded plane HHplane_2_0_80.dat
# Loaded plane HHplane_2_0_120.dat
# Loaded plane HHplane_2_0_160.dat
# Loaded plane HHplane_2_0_200.dat
# Loaded plane HHplane_2_0_240.dat
# Loaded plane HHplane_2_0_280.dat
# Loaded plane HHplane_2_0_320.dat
# Loaded plane HHplane_2_0_360.dat
# Loaded plane HHplane_2_0_400.dat
# Loaded plane HHplane_2_40_0.dat
# Loaded plane HHplane_2_40_40.dat
# Loaded plane HHplane_2_40_80.dat
# Loaded plane HHplane_2_40_120.dat
# Loaded plane HHplane_2_40_160.dat
# Loaded plane HHplane_2_40_200.dat
# Loaded plane HHplane_2_40_240.dat
# Loaded plane HHplane_2_40_280.dat
# Loaded plane HHplane_2_40_320.dat
# Loaded plane HHplane_2_40_360.dat
# Loaded plane HHplane_2_40_400.dat
# Loaded plane HHplane_2_80_0.dat
# Loaded plane HHplane_2_80_40.dat
# Loaded plane HHplane_2_80_80.dat
# Loaded plane HHplane_2_80_120.dat
# Loaded plane HHplane_2_80_160.dat
# Loaded plane HHplane_2_80_200.dat
# Loaded plane HHplane_2_80_240.dat
# Loaded plane HHplane_2_80_280.dat
# Loaded plane HHplane_2_80_320.dat
# Loaded plane HHplane_2_80_360.dat
# Loaded plane HHplane_2_80_400.dat
# Loaded plane HHplane_2_120_0.dat
# Loaded plane HHplane_2_120_40.dat
# Loaded plane HHplane_2_120_80.dat
# Loaded plane HHplane_2_120_120.dat
# Loaded plane HHplane_2_120_160.dat
# Loaded plane HHplane_2_120_200.dat
# Loaded plane HHplane_2_120_240.dat
# Loaded plane HHplane_2_120_280.dat
# Loaded plane HHplane_2_120_320.dat
# Loaded plane HHplane_2_120_360.dat
# Loaded plane HHplane_2_120_400.dat
# Loaded plane HHplane_2_160_0.dat
# Loaded plane HHplane_2_160_40.dat
# Loaded plane HHplane_2_160_80.dat
# Loaded plane HHplane_2_160_120.dat
# Loaded plane HHplane_2_160_160.dat
# Loaded plane HHplane_2_160_200.dat
# Loaded plane HHplane_2_160_240.dat
# Loaded plane HHplane_2_160_280.dat
# Loaded plane HHplane_2_160_320.dat
# Loaded plane HHplane_2_160_360.dat
# Loaded plane HHplane_2_160_400.dat
# Loaded plane HHplane_2_200_0.dat
# Loaded plane HHplane_2_200_40.dat
# Loaded plane HHplane_2_200_80.dat
# Loaded plane HHplane_2_200_120.dat
# Loaded plane HHplane_2_200_160.dat
# Loaded plane HHplane_2_200_200.dat
# Loaded plane HHplane_2_200_240.dat
# Loaded plane HHplane_2_200_280.dat
# Loaded plane HHplane_2_200_320.dat
# Loaded plane HHplane_2_200_360.dat
# Loaded plane HHplane_2_200_400.dat
# Loaded plane HHplane_2_240_0.dat
# Loaded plane HHplane_2_240_40.dat
# Loaded plane HHplane_2_240_80.dat
# Loaded plane HHplane_2_240_120.dat
# Loaded plane HHplane_2_240_160.dat
# Loaded plane HHplane_2_240_200.dat
# Loaded plane HHplane_2_240_240.dat
# Loaded plane HHplane_2_240_280.dat
# Loaded plane HHplane_2_240_320.dat
# Loaded plane HHplane_2_240_360.dat
# Loaded plane HHplane_2_240_400.dat
# Loaded plane HHplane_2_280_0.dat
# Loaded plane HHplane_2_280_40.dat
# Loaded plane HHplane_2_280_80.dat
# Loaded plane HHplane_2_280_120.dat
# Loaded plane HHplane_2_280_160.dat
# Loaded plane HHplane_2_280_200.dat
# Loaded plane HHplane_2_280_240.dat
# Loaded plane HHplane_2_280_280.dat
# Loaded plane HHplane_2_280_320.dat
# Loaded plane HHplane_2_280_360.dat
# Loaded plane HHplane_2_280_400.dat
# Loaded plane HHplane_2_320_0.dat
# Loaded plane HHplane_2_320_40.dat
# Loaded plane HHplane_2_320_80.dat
# Loaded plane HHplane_2_320_120.dat
# Loaded plane HHplane_2_320_160.dat
# Loaded plane HHplane_2_320_200.dat
# Loaded plane HHplane_2_320_240.dat
# Loaded plane HHplane_2_320_280.dat
# Loaded plane HHplane_2_320_320.dat
# Loaded plane HHplane_2_320_360.dat
# Loaded plane HHplane_2_320_400.dat
# Loaded plane HHplane_2_360_0.dat
# Loaded plane HHplane_2_360_40.dat
# Loaded plane HHplane_2_360_80.dat
# Loaded plane HHplane_2_360_120.dat
# Loaded plane HHplane_2_360_160.dat
# Loaded plane HHplane_2_360_200.dat
# Loaded plane HHplane_2_360_240.dat
# Loaded plane HHplane_2_360_280.dat
# Loaded plane HHplane_2_360_320.dat
# Loaded plane HHplane_2_360_360.dat
# Loaded plane HHplane_2_360_400.dat
# Loaded plane HHplane_2_400_0.dat
# Loaded plane HHplane_2_400_40.dat
# Loaded plane HHplane_2_400_80.dat
# Loaded plane HHplane_2_400_120.dat
# Loaded plane HHplane_2_400_160.dat
# Loaded plane HHplane_2_400_200.dat
# Loaded plane HHplane_2_400_240.dat
# Loaded plane HHplane_2_400_280.dat
# Loaded plane HHplane_2_400_320.dat
# Loaded plane HHplane_2_400_360.dat
# Loaded plane HHplane_2_400_400.dat
# Averaged over 121 planes

# %%
# Get the equivalent Kaimal spectra
#avgUlong = np.mean(all_ulongavgs)
s='20'
print("Avg Ulong = %f zavg = %f"%(avgUlong[s], zavg[s]))
Su_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s])
Sv_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s], params=windspectra.vKaimalconst)
Sw_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s], params=windspectra.wKaimalconst)

fmax = 0.6*avgUlong[s]/(8*np.sqrt(2)*dx)
allfmax[s]=fmax
print("fmax = %f"%fmax)
print("nmax = %f"%(fmax*zavg[s]/utau))
# Out:
# Avg Ulong = 5.004783 zavg = 20.000000
# fmax = 0.106167
# nmax = 12.999383

# %%
# Plot the longitudinal spectral
plt.figure(figsize=(8,8))
plt.rc('font', size=14)
plt.rc('xtick', labelsize=14)
# Plot the Nalu Wind spectra
s='20'
f=favg[s]
plt.loglog(f, f*Suu_avg[s]/utau**2, 'b--', label='Nalu-Wind [u]')
plt.loglog(f, f*Svv_avg[s]/utau**2, 'r--', label='Nalu-Wind [v]')
plt.loglog(f, f*Sww_avg[s]/utau**2, 'g--', label='Nalu-Wind [w]')

# Plot Kaimal
plt.loglog(f, Su_Kai[s],'b', lw=3, label='Kaimal [u]')
plt.loglog(f, Sv_Kai[s],'r', lw=3, label='Kaimal [v]')
plt.loglog(f, Sw_Kai[s],'g', lw=3, label='Kaimal [w]')

# Plot where the spectral cut-off is
plt.vlines(fmax, 5e-2, 1.5,lw=3, linestyle='-.')

#plt.vlines(0.0049*np.arange(1,4), 1e-1, 10, lw=1, linestyle='--')

# Formatting options
plt.ylim([2E-5, 6]);
plt.xlim([1E-5, 1]);
plt.xlabel('Frequency $f$ [Hz]')
plt.ylabel('$f\cdot S_{u,v,w}/u_{\\tau}^2$ [-]')
plt.title('Avg spectra [Stable 5 m/s, z=%sm, dx=%2.1fm]'%(s, dx))
plt.legend(loc='upper left')

# %%
# --- Paper version ---
plt.figure(figsize=(5,5),dpi=100)
plt.rc('font', size=16)
plt.rc('xtick', labelsize=14)
# Plot the Nalu Wind spectra
s='20'
f=favg[s]
plt.loglog(f, f*Suu_avg[s]/utau**2, 'b--', label='Nalu-Wind [u]')
plt.loglog(f, f*Svv_avg[s]/utau**2, 'r--', label='Nalu-Wind [v]')
plt.loglog(f, f*Sww_avg[s]/utau**2, 'g--', label='Nalu-Wind [w]')

# Plot Kaimal
plt.loglog(f, Su_Kai[s],'b', lw=3, label='Kaimal [u]')
plt.loglog(f, Sv_Kai[s],'r', lw=3, label='Kaimal [v]')
plt.loglog(f, Sw_Kai[s],'g', lw=3, label='Kaimal [w]')

# Plot where the spectral cut-off is
plt.vlines(fmax, 5e-2, 1.5,lw=3, linestyle='-.')

# Formatting options
plt.ylim([2E-2, 5]);
plt.xlim([1E-4, 1]);
plt.xlabel('Frequency $f$ [Hz]')
plt.ylabel('$f\cdot S_{i}/u_{\\tau}^2$ [-]')
plt.title('Stable 5 m/s, z=%sm, dx=%2.1fm'%(s, dx))
#plt.title('Stable 5 m/s, z=%sm'%s)
#plt.title('Avg spectra [Neutral 10 m/s, z=%sm]'%s)
#plt.legend(loc='upper left')

# %%
# Save the files
for izrow, zrow in enumerate(szvector):
    s = zrow[1]
    savefile=saveprefix+'_z%s.dat'%s
    savedat=np.vstack((favg[s], Suu_avg[s], Svv_avg[s], Sww_avg[s])).transpose()
    print('Saving %s'%savefile)
    np.savetxt(savefile,savedat,header="f, Suu, Svv, Sww")
# Out:
# Saving NaluWind_Stable05_spectra_dx02.5_z20.dat
# Saving NaluWind_Stable05_spectra_dx02.5_z40.dat
# Saving NaluWind_Stable05_spectra_dx02.5_z60.dat
