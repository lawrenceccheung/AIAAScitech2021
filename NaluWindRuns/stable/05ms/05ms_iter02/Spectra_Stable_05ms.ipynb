# %% [markdown]
# # Nalu-Wind Spectra 10x10x2.5m case

# %%
# %%capture

import sys
naluhelperdir = '../../../../Postprocessing/utilities/'
sys.path.insert(1, naluhelperdir)

# Change some display properties
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:75% !important; }</style>"))
import matplotlib.pyplot as plt
import numpy as np
import windspectra
import os.path
from matplotlib.lines import Line2D
# %matplotlib inline

# %%
# Average the spectra over multiple locations
# given by locations in planefilelist
def avgSpectraPlanefiles(planefilelist, verbose=True):
    # set initial values
    iplane = 0
    all_ulongavgs = []
    lent = 0
    # Loop through and get spectra
    for planefile in planefilelist:
        if not os.path.isfile(datadir+'/'+planefile): continue
        dat       = np.loadtxt(datadir+'/'+planefile)
        t   = dat[:,0]
        z   = dat[:,6]
        u   = dat[:,7]
        v   = dat[:,8]
        w   = dat[:,9]
        if ((iplane != 0) and (lent != len(t))): continue
        if verbose: print("Loaded plane "+planefile)
        ulong, ulat = windspectra.convertUxytoLongLat(u,v)
        all_ulongavgs.append(np.mean(ulong))
        f, Suu      = windspectra.avgWindSpectra(t, ulong, avgbins)
        f, Svv      = windspectra.avgWindSpectra(t, ulat,  avgbins)
        f, Sww      = windspectra.avgWindSpectra(t, w,     avgbins)
        if iplane == 0:
            lent    = len(t)
            favg    = f
            Suu_avg = Suu
            Svv_avg = Svv
            Sww_avg = Sww
        else:
            Suu_avg = Suu_avg + Suu
            Svv_avg = Svv_avg + Svv
            Sww_avg = Sww_avg + Sww
        iplane = iplane+1
        zavg   = np.mean(z)
    # Average the spectra
    Suu_avg = Suu_avg/iplane
    Svv_avg = Svv_avg/iplane
    Sww_avg = Sww_avg/iplane
    if verbose: print("Averaged over %i planes"%iplane)
    return favg, Suu_avg, Svv_avg, Sww_avg, np.mean(all_ulongavgs), zavg

# %%
# Define some dicts to save stuff
Suu_avg={}
Svv_avg={}
Sww_avg={}
avgUlong={}
zavg={}
favg={}
allfmax={}
Su_Kai={}
Sv_Kai={}
Sw_Kai={}

# %%
# Define data locations and variables
#datadir  = '/ascldap/users/lcheung/nscratch/Torque2020/Runs/stable/05ms/mini05_iter05/statsData/extractpoints/HHplane_plane0'
#datadir = '/ascldap/users/lcheung/nscratch/Torque2020/Runs/stable/05ms/mini05_iter18/extractpoints/HHplane_plane0'
datadir = 'rundir/spectra/HHplane_plane0/'
planeprefix = 'HHplane_'
planenum = 0
jvector  = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75] 
ivector  = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75] 

szvector = [[0, '20'],  
            #[1, '40'], 
            #[2, '60'],
           ]
# Averaging bins
avgbins = [[15000.5, 18300],[16650.5, 19950]] # #[[20000.5, 23300],[21650.5, 24950]]

# Friction velocity.  Eventually this should be pulled from the ABL stats file
utau     = 0.14238698987034834

dx          = 10.0 # Grid spacing
saveprefix  ='NaluWind_Stable05_spectra_dx%04.1f'%dx

# %%
# Construct the list of planefiles and average
s='20'
planefiles=[]
for j in jvector:
    for i in ivector:
        planefiles.append(planeprefix+'%i_%i_%i.dat'%(planenum, j,i))
favg[s], Suu_avg[s], Svv_avg[s], Sww_avg[s], avgUlong[s], zavg[s] = avgSpectraPlanefiles(planefiles, verbose=True)
# Out:
# Loaded plane HHplane_0_0_0.dat
# Loaded plane HHplane_0_0_5.dat
# Loaded plane HHplane_0_0_10.dat
# Loaded plane HHplane_0_0_15.dat
# Loaded plane HHplane_0_0_20.dat
# Loaded plane HHplane_0_0_25.dat
# Loaded plane HHplane_0_0_30.dat
# Loaded plane HHplane_0_0_35.dat
# Loaded plane HHplane_0_0_40.dat
# Loaded plane HHplane_0_0_45.dat
# Loaded plane HHplane_0_0_50.dat
# Loaded plane HHplane_0_0_55.dat
# Loaded plane HHplane_0_0_60.dat
# Loaded plane HHplane_0_0_65.dat
# Loaded plane HHplane_0_0_70.dat
# Loaded plane HHplane_0_0_75.dat
# Loaded plane HHplane_0_5_0.dat
# Loaded plane HHplane_0_5_5.dat
# Loaded plane HHplane_0_5_10.dat
# Loaded plane HHplane_0_5_15.dat
# Loaded plane HHplane_0_5_20.dat
# Loaded plane HHplane_0_5_25.dat
# Loaded plane HHplane_0_5_30.dat
# Loaded plane HHplane_0_5_35.dat
# Loaded plane HHplane_0_5_40.dat
# Loaded plane HHplane_0_5_45.dat
# Loaded plane HHplane_0_5_50.dat
# Loaded plane HHplane_0_5_55.dat
# Loaded plane HHplane_0_5_60.dat
# Loaded plane HHplane_0_5_65.dat
# Loaded plane HHplane_0_5_70.dat
# Loaded plane HHplane_0_5_75.dat
# Loaded plane HHplane_0_10_0.dat
# Loaded plane HHplane_0_10_5.dat
# Loaded plane HHplane_0_10_10.dat
# Loaded plane HHplane_0_10_15.dat
# Loaded plane HHplane_0_10_20.dat
# Loaded plane HHplane_0_10_25.dat
# Loaded plane HHplane_0_10_30.dat
# Loaded plane HHplane_0_10_35.dat
# Loaded plane HHplane_0_10_40.dat
# Loaded plane HHplane_0_10_45.dat
# Loaded plane HHplane_0_10_50.dat
# Loaded plane HHplane_0_10_55.dat
# Loaded plane HHplane_0_10_60.dat
# Loaded plane HHplane_0_10_65.dat
# Loaded plane HHplane_0_10_70.dat
# Loaded plane HHplane_0_10_75.dat
# Loaded plane HHplane_0_15_0.dat
# Loaded plane HHplane_0_15_5.dat
# Loaded plane HHplane_0_15_10.dat
# Loaded plane HHplane_0_15_15.dat
# Loaded plane HHplane_0_15_20.dat
# Loaded plane HHplane_0_15_25.dat
# Loaded plane HHplane_0_15_30.dat
# Loaded plane HHplane_0_15_35.dat
# Loaded plane HHplane_0_15_40.dat
# Loaded plane HHplane_0_15_45.dat
# Loaded plane HHplane_0_15_50.dat
# Loaded plane HHplane_0_15_55.dat
# Loaded plane HHplane_0_15_60.dat
# Loaded plane HHplane_0_15_65.dat
# Loaded plane HHplane_0_15_70.dat
# Loaded plane HHplane_0_15_75.dat
# Loaded plane HHplane_0_20_0.dat
# Loaded plane HHplane_0_20_5.dat
# Loaded plane HHplane_0_20_10.dat
# Loaded plane HHplane_0_20_15.dat
# Loaded plane HHplane_0_20_20.dat
# Loaded plane HHplane_0_20_25.dat
# Loaded plane HHplane_0_20_30.dat
# Loaded plane HHplane_0_20_35.dat
# Loaded plane HHplane_0_20_40.dat
# Loaded plane HHplane_0_20_45.dat
# Loaded plane HHplane_0_20_50.dat
# Loaded plane HHplane_0_20_55.dat
# Loaded plane HHplane_0_20_60.dat
# Loaded plane HHplane_0_20_65.dat
# Loaded plane HHplane_0_20_70.dat
# Loaded plane HHplane_0_20_75.dat
# Loaded plane HHplane_0_25_0.dat
# Loaded plane HHplane_0_25_5.dat
# Loaded plane HHplane_0_25_10.dat
# Loaded plane HHplane_0_25_15.dat
# Loaded plane HHplane_0_25_20.dat
# Loaded plane HHplane_0_25_25.dat
# Loaded plane HHplane_0_25_30.dat
# Loaded plane HHplane_0_25_35.dat
# Loaded plane HHplane_0_25_40.dat
# Loaded plane HHplane_0_25_45.dat
# Loaded plane HHplane_0_25_50.dat
# Loaded plane HHplane_0_25_55.dat
# Loaded plane HHplane_0_25_60.dat
# Loaded plane HHplane_0_25_65.dat
# Loaded plane HHplane_0_25_70.dat
# Loaded plane HHplane_0_25_75.dat
# Loaded plane HHplane_0_30_0.dat
# Loaded plane HHplane_0_30_5.dat
# Loaded plane HHplane_0_30_10.dat
# Loaded plane HHplane_0_30_15.dat
# Loaded plane HHplane_0_30_20.dat
# Loaded plane HHplane_0_30_25.dat
# Loaded plane HHplane_0_30_30.dat
# Loaded plane HHplane_0_30_35.dat
# Loaded plane HHplane_0_30_40.dat
# Loaded plane HHplane_0_30_45.dat
# Loaded plane HHplane_0_30_50.dat
# Loaded plane HHplane_0_30_55.dat
# Loaded plane HHplane_0_30_60.dat
# Loaded plane HHplane_0_30_65.dat
# Loaded plane HHplane_0_30_70.dat
# Loaded plane HHplane_0_30_75.dat
# Loaded plane HHplane_0_35_0.dat
# Loaded plane HHplane_0_35_5.dat
# Loaded plane HHplane_0_35_10.dat
# Loaded plane HHplane_0_35_15.dat
# Loaded plane HHplane_0_35_20.dat
# Loaded plane HHplane_0_35_25.dat
# Loaded plane HHplane_0_35_30.dat
# Loaded plane HHplane_0_35_35.dat
# Loaded plane HHplane_0_35_40.dat
# Loaded plane HHplane_0_35_45.dat
# Loaded plane HHplane_0_35_50.dat
# Loaded plane HHplane_0_35_55.dat
# Loaded plane HHplane_0_35_60.dat
# Loaded plane HHplane_0_35_65.dat
# Loaded plane HHplane_0_35_70.dat
# Loaded plane HHplane_0_35_75.dat
# Loaded plane HHplane_0_40_0.dat
# Loaded plane HHplane_0_40_5.dat
# Loaded plane HHplane_0_40_10.dat
# Loaded plane HHplane_0_40_15.dat
# Loaded plane HHplane_0_40_20.dat
# Loaded plane HHplane_0_40_25.dat
# Loaded plane HHplane_0_40_30.dat
# Loaded plane HHplane_0_40_35.dat
# Loaded plane HHplane_0_40_40.dat
# Loaded plane HHplane_0_40_45.dat
# Loaded plane HHplane_0_40_50.dat
# Loaded plane HHplane_0_40_55.dat
# Loaded plane HHplane_0_40_60.dat
# Loaded plane HHplane_0_40_65.dat
# Loaded plane HHplane_0_40_70.dat
# Loaded plane HHplane_0_40_75.dat
# Loaded plane HHplane_0_45_0.dat
# Loaded plane HHplane_0_45_5.dat
# Loaded plane HHplane_0_45_10.dat
# Loaded plane HHplane_0_45_15.dat
# Loaded plane HHplane_0_45_20.dat
# Loaded plane HHplane_0_45_25.dat
# Loaded plane HHplane_0_45_30.dat
# Loaded plane HHplane_0_45_35.dat
# Loaded plane HHplane_0_45_40.dat
# Loaded plane HHplane_0_45_45.dat
# Loaded plane HHplane_0_45_50.dat
# Loaded plane HHplane_0_45_55.dat
# Loaded plane HHplane_0_45_60.dat
# Loaded plane HHplane_0_45_65.dat
# Loaded plane HHplane_0_45_70.dat
# Loaded plane HHplane_0_45_75.dat
# Loaded plane HHplane_0_50_0.dat
# Loaded plane HHplane_0_50_5.dat
# Loaded plane HHplane_0_50_10.dat
# Loaded plane HHplane_0_50_15.dat
# Loaded plane HHplane_0_50_20.dat
# Loaded plane HHplane_0_50_25.dat
# Loaded plane HHplane_0_50_30.dat
# Loaded plane HHplane_0_50_35.dat
# Loaded plane HHplane_0_50_40.dat
# Loaded plane HHplane_0_50_45.dat
# Loaded plane HHplane_0_50_50.dat
# Loaded plane HHplane_0_50_55.dat
# Loaded plane HHplane_0_50_60.dat
# Loaded plane HHplane_0_50_65.dat
# Loaded plane HHplane_0_50_70.dat
# Loaded plane HHplane_0_50_75.dat
# Loaded plane HHplane_0_55_0.dat
# Loaded plane HHplane_0_55_5.dat
# Loaded plane HHplane_0_55_10.dat
# Loaded plane HHplane_0_55_15.dat
# Loaded plane HHplane_0_55_20.dat
# Loaded plane HHplane_0_55_25.dat
# Loaded plane HHplane_0_55_30.dat
# Loaded plane HHplane_0_55_35.dat
# Loaded plane HHplane_0_55_40.dat
# Loaded plane HHplane_0_55_45.dat
# Loaded plane HHplane_0_55_50.dat
# Loaded plane HHplane_0_55_55.dat
# Loaded plane HHplane_0_55_60.dat
# Loaded plane HHplane_0_55_65.dat
# Loaded plane HHplane_0_55_70.dat
# Loaded plane HHplane_0_55_75.dat
# Loaded plane HHplane_0_60_0.dat
# Loaded plane HHplane_0_60_5.dat
# Loaded plane HHplane_0_60_10.dat
# Loaded plane HHplane_0_60_15.dat
# Loaded plane HHplane_0_60_20.dat
# Loaded plane HHplane_0_60_25.dat
# Loaded plane HHplane_0_60_30.dat
# Loaded plane HHplane_0_60_35.dat
# Loaded plane HHplane_0_60_40.dat
# Loaded plane HHplane_0_60_45.dat
# Loaded plane HHplane_0_60_50.dat
# Loaded plane HHplane_0_60_55.dat
# Loaded plane HHplane_0_60_60.dat
# Loaded plane HHplane_0_60_65.dat
# Loaded plane HHplane_0_60_70.dat
# Loaded plane HHplane_0_60_75.dat
# Loaded plane HHplane_0_65_0.dat
# Loaded plane HHplane_0_65_5.dat
# Loaded plane HHplane_0_65_10.dat
# Loaded plane HHplane_0_65_15.dat
# Loaded plane HHplane_0_65_20.dat
# Loaded plane HHplane_0_65_25.dat
# Loaded plane HHplane_0_65_30.dat
# Loaded plane HHplane_0_65_35.dat
# Loaded plane HHplane_0_65_40.dat
# Loaded plane HHplane_0_65_45.dat
# Loaded plane HHplane_0_65_50.dat
# Loaded plane HHplane_0_65_55.dat
# Loaded plane HHplane_0_65_60.dat
# Loaded plane HHplane_0_65_65.dat
# Loaded plane HHplane_0_65_70.dat
# Loaded plane HHplane_0_65_75.dat
# Loaded plane HHplane_0_70_0.dat
# Loaded plane HHplane_0_70_5.dat
# Loaded plane HHplane_0_70_10.dat
# Loaded plane HHplane_0_70_15.dat
# Loaded plane HHplane_0_70_20.dat
# Loaded plane HHplane_0_70_25.dat
# Loaded plane HHplane_0_70_30.dat
# Loaded plane HHplane_0_70_35.dat
# Loaded plane HHplane_0_70_40.dat
# Loaded plane HHplane_0_70_45.dat
# Loaded plane HHplane_0_70_50.dat
# Loaded plane HHplane_0_70_55.dat
# Loaded plane HHplane_0_70_60.dat
# Loaded plane HHplane_0_70_65.dat
# Loaded plane HHplane_0_70_70.dat
# Loaded plane HHplane_0_70_75.dat
# Loaded plane HHplane_0_75_0.dat
# Loaded plane HHplane_0_75_5.dat
# Loaded plane HHplane_0_75_10.dat
# Loaded plane HHplane_0_75_15.dat
# Loaded plane HHplane_0_75_20.dat
# Loaded plane HHplane_0_75_25.dat
# Loaded plane HHplane_0_75_30.dat
# Loaded plane HHplane_0_75_35.dat
# Loaded plane HHplane_0_75_40.dat
# Loaded plane HHplane_0_75_45.dat
# Loaded plane HHplane_0_75_50.dat
# Loaded plane HHplane_0_75_55.dat
# Loaded plane HHplane_0_75_60.dat
# Loaded plane HHplane_0_75_65.dat
# Loaded plane HHplane_0_75_70.dat
# Loaded plane HHplane_0_75_75.dat
# Averaged over 256 planes

# %%
# Get the equivalent Kaimal spectra
#avgUlong = np.mean(all_ulongavgs)
s='20'
print("Avg Ulong = %f zavg = %f"%(avgUlong[s], zavg[s]))
Su_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s])
Sv_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s], params=windspectra.vKaimalconst)
Sw_Kai[s] = windspectra.getKaimal(favg[s], zavg[s], avgUlong[s], params=windspectra.wKaimalconst)

#dx   = 10
fmax = 0.6*avgUlong[s]/(8*np.sqrt(2)*dx)
allfmax[s]=fmax
print("fmax = %f"%fmax)
print("nmax = %f"%(fmax*zavg[s]/utau))
# Out:
# Avg Ulong = 5.002816 zavg = 20.000000
# fmax = 0.026531
# nmax = 3.726666

# %%
# Plot the longitudinal spectral
plt.figure(figsize=(8,8))
plt.rc('font', size=14)
plt.rc('xtick', labelsize=14)
# Plot the Nalu Wind spectra
s='20'
f=favg[s]
plt.loglog(f, f*Suu_avg[s]/utau**2, 'b--', label='Nalu-Wind [u]')
plt.loglog(f, f*Svv_avg[s]/utau**2, 'r--', label='Nalu-Wind [v]')
plt.loglog(f, f*Sww_avg[s]/utau**2, 'g--', label='Nalu-Wind [w]')

# Plot Kaimal
plt.loglog(f, Su_Kai[s],'b', lw=3, label='Kaimal [u]')
plt.loglog(f, Sv_Kai[s],'r', lw=3, label='Kaimal [v]')
plt.loglog(f, Sw_Kai[s],'g', lw=3, label='Kaimal [w]')

# Plot where the spectral cut-off is
plt.vlines(fmax, 5e-2, 1.5,lw=3, linestyle='-.')

#plt.vlines(0.0049*np.arange(1,4), 1e-1, 10, lw=1, linestyle='--')

# Formatting options
plt.ylim([2E-5, 6]);
plt.xlim([1E-5, 1]);
plt.xlabel('Frequency $f$ [Hz]')
plt.ylabel('$f\cdot S_{u,v,w}/u_{\\tau}^2$ [-]')
plt.title('Avg spectra [Stable 5 m/s, z=%sm, dx=%2.1fm]'%(s, dx))
plt.legend(loc='upper left')

# %%
# --- Paper version ---
plt.figure(figsize=(5,5),dpi=100)
plt.rc('font', size=16)
plt.rc('xtick', labelsize=14)
# Plot the Nalu Wind spectra
s='20'
f=favg[s]
plt.loglog(f, f*Suu_avg[s]/utau**2, 'b--', label='Nalu-Wind [u]')
plt.loglog(f, f*Svv_avg[s]/utau**2, 'r--', label='Nalu-Wind [v]')
plt.loglog(f, f*Sww_avg[s]/utau**2, 'g--', label='Nalu-Wind [w]')

# Plot Kaimal
plt.loglog(f, Su_Kai[s],'b', lw=3, label='Kaimal [u]')
plt.loglog(f, Sv_Kai[s],'r', lw=3, label='Kaimal [v]')
plt.loglog(f, Sw_Kai[s],'g', lw=3, label='Kaimal [w]')

# Plot where the spectral cut-off is
plt.vlines(fmax, 5e-2, 1.5,lw=3, linestyle='-.')

# Formatting options
plt.ylim([2E-2, 5]);
plt.xlim([1E-4, 1]);
plt.xlabel('Frequency $f$ [Hz]')
plt.ylabel('$f\cdot S_{i}/u_{\\tau}^2$ [-]')
#plt.title('Stable 5 m/s, z=%sm'%s)
plt.title('Stable 5 m/s, z=%sm, dx=%2.1fm'%(s, dx))
#plt.title('Avg spectra [Neutral 10 m/s, z=%sm]'%s)
#plt.legend(loc='upper left')
# Out:
# Text(0.5,1,'Stable 5 m/s, z=20m, dx=10.0m')

# %%
# Save the files
for izrow, zrow in enumerate(szvector):
    s = zrow[1]
    savefile=saveprefix+'_z%s.dat'%s
    savedat=np.vstack((favg[s], Suu_avg[s], Svv_avg[s], Sww_avg[s])).transpose()
    print('Saving %s'%savefile)
    np.savetxt(savefile,savedat,header="f, Suu, Svv, Sww")
# Out:
# Saving NaluWind_Stable05_spectra_dx10.0_z20.dat
